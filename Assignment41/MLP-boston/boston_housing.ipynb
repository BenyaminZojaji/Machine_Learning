# %% [markdown]
# <a href="https://colab.research.google.com/github/BenyaminZojaji/Machine_Learning/blob/main/Assignment41/MLP-boston/boston_housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wandb

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import wandb
from wandb.keras import WandbCallback

# %%
wandb.login
# Out:
# <function wandb.sdk.wandb_login.login>

# %%
wandb.init(project='Boston Housing')
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                     Syncing run <strong><a href="https://wandb.ai/benyaminzojaji/Boston%20Housing/runs/1ur0u3xn" target="_blank">vocal-field-1</a></strong> to <a href="https://wandb.ai/benyaminzojaji/Boston%20Housing" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/benyaminzojaji/Boston%20Housing/runs/1ur0u3xn?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
config = wandb.config
config.learning_rate = 0.001

# %% [markdown]
# ### Data

# %%
dataset = tf.keras.datasets.boston_housing
(X_train, Y_train), (X_test, Y_test) = dataset.load_data()
# Out:
# ...
# 65536/57026 [==================================] - 0s 0us/step

# %% [markdown]
# ### Model

# %%
model = tf.keras.models.Sequential([
    Dense(24, input_dim=13, activation='sigmoid'), #HL1
    Dense(8, activation='sigmoid'), # HL2
    Dense(4, activation='sigmoid'), # HL3
    Dense(1, activation='linear') # OL
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=config.learning_rate),
loss=tf.keras.losses.MeanSquaredError()
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 24)                336
#
#  dense_1 (Dense)             (None, 8)                 200
#
#  dense_2 (Dense)             (None, 4)                 36
#
#  dense_3 (Dense)             (None, 1)                 5
#
# ...
# Total params: 577
# Trainable params: 577
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, Y_train, epochs=500, callbacks=[WandbCallback()])
# Out:
# Epoch 1/500
# 13/13 [==============================] - 0s 3ms/step - loss: 87.5090
# Epoch 2/500
# 13/13 [==============================] - 0s 2ms/step - loss: 87.4423
# Epoch 3/500
# 13/13 [==============================] - 0s 2ms/step - loss: 87.3916
# Epoch 4/500
# 13/13 [==============================] - 0s 2ms/step - loss: 87.3176
# Epoch 5/500
# 13/13 [==============================] - 0s 2ms/step - loss: 87.2607
# Epoch 6/500
# 13/13 [==============================] - 0s 3ms/step - loss: 87.2092
# Epoch 7/500
# 13/13 [==============================] - 0s 2ms/step - loss: 87.1389
# Epoch 8/500
# 13/13 [==============================] - 0s 2ms/step - loss: 87.0915
# Epoch 9/500
# 13/13 [==============================] - 0s 2ms/step - loss: 87.0321
# Epoch 10/500
# 13/13 [==============================] - 0s 2ms/step - loss: 86.9858
# Epoch 11/500
# 13/13 [==============================] - 0s 2ms/step - loss: 86.9234
# Epoch 12/500
# ...

# %%
model.evaluate(X_test, Y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 34.6482
# 34.64817810058594

# %% [markdown]
# ### Interfrence

# %%
my_house = np.array([[0.00632, 18.0, 2.31, 0.0, 0.532, 6.575, 65.2, 4.09, 1.0, 296.0, 15.3, 396.9, 4.98]])

model.predict(my_house)
# Out:
# array([[29.303505]], dtype=float32)
