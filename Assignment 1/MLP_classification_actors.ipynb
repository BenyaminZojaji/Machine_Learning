# %% [markdown]
# <a href="https://colab.research.google.com/github/BenyaminZojaji/Machine_Learning/blob/main/Assignment%201/MLP_classification_actors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wandb

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
import pandas as pd
import wandb
from wandb.keras import WandbCallback

# %%
wandb.init(project="actors-classification", entity="benyaminzojaji")
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                     Syncing run <strong><a href="https://wandb.ai/benyaminzojaji/actors-classification/runs/1ydsdfct" target="_blank">sunny-durian-1</a></strong> to <a href="https://wandb.ai/benyaminzojaji/actors-classification" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/benyaminzojaji/actors-classification/runs/1ydsdfct?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %% [markdown]
# ### Load data

# %%
df = pd.read_csv('/content/arcfaceData.csv')
df.head()
# Out:
#           0         1         2         3  ...       509       510       511  label
# 0  0.088835  0.424528  0.151461  0.125330  ...  0.195647  0.581766  0.276890      0
# 1  0.062198  0.274320  0.102746  0.187975  ... -0.294132  0.374689  0.201106      0
# 2  0.157432  0.216765 -0.134859  0.096746  ...  0.242365  0.288665  0.251481      0
# 3 -0.240629  0.538784 -0.175988 -0.484024  ...  0.005703 -0.410898 -1.128452      0
# 4 -0.283768  0.598225 -0.267680 -0.477669  ... -0.057037 -0.458541 -1.352975      0
#
# [5 rows x 513 columns]

# %% [markdown]
# ### train/test split

# %%
Y = df[['label']]
X = df.drop(['label'], axis=1)

# %%
Y
# Out:
#      label
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 194      3
# 195      3
# 196      3
# 197      3
# 198      3
#
# [199 rows x 1 columns]

# %%
X.head()
# Out:
#           0         1         2  ...       509       510       511
# 0  0.088835  0.424528  0.151461  ...  0.195647  0.581766  0.276890
# 1  0.062198  0.274320  0.102746  ... -0.294132  0.374689  0.201106
# 2  0.157432  0.216765 -0.134859  ...  0.242365  0.288665  0.251481
# 3 -0.240629  0.538784 -0.175988  ...  0.005703 -0.410898 -1.128452
# 4 -0.283768  0.598225 -0.267680  ... -0.057037 -0.458541 -1.352975
#
# [5 rows x 512 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=24)

# %% [markdown]
# ### Model

# %%
model = tf.keras.models.Sequential([
    Dense(64, input_dim=512, activation='relu'),
    Dense(128, activation='relu'),
    #Dense(128, activation='relu'), # tanh relu sigmoid
    Dense(512, activation='relu'),
    Dense(4, activation='softmax') # OL sigmoid linear  softmax
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
loss='sparse_categorical_crossentropy',
metrics=['accuracy']
)

# %%
model.fit(X_train, Y_train, epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 5ms/step - loss: 1.3706 - accuracy: 0.3585
# Epoch 2/100
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2384 - accuracy: 0.5283
# Epoch 3/100
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0498 - accuracy: 0.5975
# Epoch 4/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8923 - accuracy: 0.6541
# Epoch 5/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7774 - accuracy: 0.6038
# Epoch 6/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.7317 - accuracy: 0.6855
# Epoch 7/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6613 - accuracy: 0.7044
# Epoch 8/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6856 - accuracy: 0.6730
# Epoch 9/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6488 - accuracy: 0.6918
# Epoch 10/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6132 - accuracy: 0.7421
# Epoch 11/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5630 - accuracy: 0.7799
# Epoch 12/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5471 - accuracy: 0.7610
# Epoch 13/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5412 - accuracy: 0.7925
# Epoch 14/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5025 - accuracy: 0.8050
# Epoch 15/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4771 - accuracy: 0.8050
# Epoch 16/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4839 - accuracy: 0.8113
# Epoch 17/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4445 - accuracy: 0.8302
# Epoch 18/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3945 - accuracy: 0.8679
# Epoch 19/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.4664 - accuracy: 0.7862
# Epoch 20/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4799 - accuracy: 0.8239
# Epoch 21/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4214 - accuracy: 0.8239
# Epoch 22/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3694 - accuracy: 0.8616
# Epoch 23/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3166 - accuracy: 0.8805
# Epoch 24/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3145 - accuracy: 0.8679
# Epoch 25/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3970 - accuracy: 0.8553
# Epoch 26/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3384 - accuracy: 0.8491
# Epoch 27/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3368 - accuracy: 0.8679
# Epoch 28/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2955 - accuracy: 0.9057
# Epoch 29/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2549 - accuracy: 0.8931
# Epoch 30/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2607 - accuracy: 0.9057
# Epoch 31/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3535 - accuracy: 0.8616
# Epoch 32/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3783 - accuracy: 0.8742
# Epoch 33/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3304 - accuracy: 0.8616
# Epoch 34/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3195 - accuracy: 0.8805
# Epoch 35/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2680 - accuracy: 0.9182
# Epoch 36/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3600 - accuracy: 0.8302
# Epoch 37/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3443 - accuracy: 0.8553
# Epoch 38/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2652 - accuracy: 0.9057
# Epoch 39/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2165 - accuracy: 0.9119
# Epoch 40/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2404 - accuracy: 0.9182
# Epoch 41/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2320 - accuracy: 0.9119
# Epoch 42/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2138 - accuracy: 0.9119
# Epoch 43/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2054 - accuracy: 0.9308
# Epoch 44/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2079 - accuracy: 0.8994
# Epoch 45/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1511 - accuracy: 0.9434
# Epoch 46/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1774 - accuracy: 0.9497
# Epoch 47/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1534 - accuracy: 0.9371
# Epoch 48/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1436 - accuracy: 0.9623
# Epoch 49/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2037 - accuracy: 0.8994
# Epoch 50/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.2495 - accuracy: 0.9057
# Epoch 51/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1210 - accuracy: 0.9623
# Epoch 52/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1398 - accuracy: 0.9560
# Epoch 53/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1302 - accuracy: 0.9623
# Epoch 54/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1089 - accuracy: 0.9748
# Epoch 55/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0753 - accuracy: 0.9686
# Epoch 56/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0905 - accuracy: 0.9686
# Epoch 57/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0869 - accuracy: 0.9623
# Epoch 58/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0958 - accuracy: 0.9748
# Epoch 59/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0867 - accuracy: 0.9748
# Epoch 60/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0645 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1027 - accuracy: 0.9434
# Epoch 62/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0913 - accuracy: 0.9623
# Epoch 63/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0623 - accuracy: 0.9811
# Epoch 64/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0594 - accuracy: 0.9811
# Epoch 65/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0497 - accuracy: 0.9937
# Epoch 66/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0466 - accuracy: 0.9874
# Epoch 67/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0587 - accuracy: 0.9811
# Epoch 68/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1007 - accuracy: 0.9560
# Epoch 69/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0821 - accuracy: 0.9623
# Epoch 70/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1610 - accuracy: 0.9182
# Epoch 71/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1969 - accuracy: 0.9308
# Epoch 72/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1612 - accuracy: 0.9182
# Epoch 73/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1208 - accuracy: 0.9623
# Epoch 74/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1427 - accuracy: 0.9497
# Epoch 75/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1356 - accuracy: 0.9371
# Epoch 76/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0896 - accuracy: 0.9686
# Epoch 77/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0638 - accuracy: 0.9874
# Epoch 78/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0440 - accuracy: 0.9937
# Epoch 79/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0303 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 1.0000

# %% [markdown]
# ### Evaluate

# %%
model.evaluate(X_test, Y_test)
# Out:
# 2/2 [==============================] - 0s 11ms/step - loss: 0.9178 - accuracy: 0.8250
# [0.9178392291069031, 0.824999988079071]
